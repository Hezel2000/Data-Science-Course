# %% [markdown]
# # Dictionary – another type of list

# %%
[1, 2, 3, 4, 5]

# %%
dict1 = {
    'Name': ['Dominik', 'Claudia', 'Chantal', 'Mark'],
    'Height': [190, 192, 176, 181]  # in cm
}

# %%
dict1
# Out:
# {'Name': ['Dominik', 'Claudia', 'Chantal', 'Mark'],
#  'Height': [190, 192, 176, 181]}

# %%
import pandas as pd

# %%
pd.DataFrame(dict1)
# Out:
#       Name  Height
# 0  Dominik     190
# 1  Claudia     192
# 2  Chantal     176
# 3     Mark     181

# %%
dict2 = {
    'Name': ['Dominik', 'Claudia', 'Chantal', 'Mark'],
    'body parameters': {'Height': [190, 192, 176, 181], 'Weight': [94, 92, 71, 105], 'eye colour': ['blue', 'green', 'brown']}
}

# %%
dict2['body parameters']['eye colour'][0]
# Out:
# 'blue'

# %%
dict3 = {
    'animal': 'cat',
    'name': 'furbal',
    vaccinated: 'yes',
    'born': 2018
    'legs': 4
}
# Out:
#   File "<ipython-input-1-24b6af41bc96>", line 5
#     'born': 2018
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
